# %% [markdown]
# <a href="https://colab.research.google.com/github/LuchoValr/Pruebas-codigos/blob/main/Theeffect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install linearmodels
import linearmodels as lm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.5 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 77 kB 6.9 MB/s
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.1.5 requires typing-extensions<4.2.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.4.0 which is incompatible.
# spacy 3.4.2 requires typing-extensions<4.2.0,>=3.7.4; python_version < "3.8", but you have typing-extensions 4.4.0 which is incompatible.
# ...

# %%
# !pip install causaldata
from causaldata import organ_donations
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.6 MB 4.1 MB/s
# ...
#   Created wheel for causaldata: filename=causaldata-0.1.3-py3-none-any.whl size=2645627 sha256=4364785e1dd5f3afaecf206df07adb36c9f4af4b3b563e71ce6ab67f761e65af
#   Stored in directory: /root/.cache/pip/wheels/ec/33/83/c92016fcfb4ded0052ff5c64a395d08dafd2de8943ad248460
# Successfully built causaldata
# ...

# %%
od=organ_donations.load_pandas().data
od
# Out:
#        State Quarter    Rate  Quarter_Num
# 0     Alaska  Q42010  0.7500            1
# 1     Alaska  Q12011  0.7700            2
# 2     Alaska  Q22011  0.7700            3
# 3     Alaska  Q32011  0.7800            4
# 4     Alaska  Q42011  0.7800            5
# ..       ...     ...     ...          ...
# 157  Wyoming  Q12011  0.5946            2
# 158  Wyoming  Q22011  0.5937            3
# 159  Wyoming  Q32011  0.5911            4
# 160  Wyoming  Q42011  0.5854            5
# 161  Wyoming  Q12012  0.5881            6
#
# [162 rows x 4 columns]

# %%
od['California']=od['State']=='California'

# %%
od['After']=od['Quarter_Num']>3

# %%
od['Treated']=1*(od['California']&od['After'])

# %%
od
# Out:
#        State Quarter    Rate  Quarter_Num  California  After  Treated
# 0     Alaska  Q42010  0.7500            1       False  False        0
# 1     Alaska  Q12011  0.7700            2       False  False        0
# 2     Alaska  Q22011  0.7700            3       False  False        0
# 3     Alaska  Q32011  0.7800            4       False   True        0
# 4     Alaska  Q42011  0.7800            5       False   True        0
# ..       ...     ...     ...          ...         ...    ...      ...
# 157  Wyoming  Q12011  0.5946            2       False  False        0
# 158  Wyoming  Q22011  0.5937            3       False  False        0
# 159  Wyoming  Q32011  0.5911            4       False   True        0
# 160  Wyoming  Q42011  0.5854            5       False   True        0
# 161  Wyoming  Q12012  0.5881            6       False   True        0
#
# [162 rows x 7 columns]
